# %% [markdown]
# ## Load packages
# * In this exercise, you'll work on the "Emotion detection" model, which we'll explain below.
# * Let's load the required packages.

# %%
import numpy as np
import csv
import pandas as pd
import datetime, os
import tensorflow as tf
from sklearn.metrics import classification_report
from tensorflow import keras
from tensorflow.keras import layers
#from keras import layers
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from tensorflow.keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from kt_utils import *
from tensorflow.keras.callbacks import TensorBoard
from keras.callbacks.callbacks import ModelCheckpoint
#import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# %matplotlib inline

logdir = '/Users/bassler/Desktop/Documents/dl_chem_genetics/logs/'
tensorboard = TensorBoard(log_dir="/Users/bassler/Desktop/Documents/dl_chem_genetics/logs/")
# Out:
# Using TensorFlow backend.

# %%
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# %% [markdown]
# **Note**: As you can see, we've imported a lot of functions from Keras. You can use them by calling them directly in your code. Ex: `X = Input(...)` or `X = ZeroPadding2D(...)`.
#
# In other words, unlike TensorFlow, you don't have to create the graph and then make a separate `sess.run()` call to evaluate those variables.

# %%
#X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# Normalize image vectors
#X_train = X_train_orig/255.
#X_test = X_test_orig/255.

# Reshape
#Y_train = Y_train_orig.T
#Y_test = Y_test_orig.T

#print ("number of training examples = " + str(X_train.shape[0]))
#print ("number of test examples = " + str(X_test.shape[0]))
#print ("X_train shape: " + str(X_train.shape))
#print ("Y_train shape: " + str(Y_train.shape))
#print ("X_test shape: " + str(X_test.shape))
#print ("Y_test shape: " + str(Y_test.shape))

# %%
#####Predict MoA from chemical genetics#####

#X_train_test = np.random.randn(600, 4000)
#Y_train_test = np.random.randn(600, 1)


#X_test_test = np.random.randn(200, 4000)
#Y_test_test = np.random.randn(200, 1)


#data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/MoA/X_test.csv")))
#X_test = np.array(data).astype("float").T

#data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/MoA/X_train.csv")))
#X_train = np.array(data).astype("float").T

#data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/MoA/X_predict.csv")))
#X_predict = np.array(data).astype("float").T

#data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/MoA/Y_test.csv")))
#Y_test = np.array(data).astype("float").T
#Y_test = tf.keras.backend.one_hot(Y_test, 4) [0]

#data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/MoA/Y_train.csv")))
#Y_train = np.array(data).astype("float").T
#Y_train = tf.keras.backend.one_hot(Y_train, 4) [0]

#names_predictions = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/MoA/Predict_names.csv")))

#print ("number of training examples = " + str(X_train.shape[0]))
#print ("number of test examples = " + str(X_test.shape[0]))
#print ("X_train shape: " + str(X_train.shape))
#print ("Y_train shape: " + str(Y_train.shape))
#print ("X_test shape: " + str(X_test.shape))
#print ("Y_test shape: " + str(Y_test.shape))
#print ("X_predict shape: " + str(X_predict.shape))

# %%
#####Predict drug-drug interactions#####

data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/X_test.csv")))
X_test = np.array(data).astype("float").T
#X_test = np.array(X_test).T

data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/X_train.csv")))
X_train = np.array(data).astype("float").T
#X_train = np.array(X_train).T

data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/X_predict.csv")))
X_predict = np.array(data).astype("float").T
#X_predict = np.array(X_predict).T

data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/Y_test.csv")))
Y_test = np.array(data).astype("float").T
Y_test = tf.keras.backend.one_hot(Y_test, 3) [0]


data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/Y_train.csv")))
Y_train = np.array(data).astype("float").T
Y_train = tf.keras.backend.one_hot(Y_train, 3) [0]


data = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/Y_predict.csv")))
Y_predict = np.array(data).astype("float").T
Y_predict = tf.one_hot(Y_predict, 3) [0]


#names_predictions = list(csv.reader(open("/Users/bassler/Desktop/Documents/dl_chem_genetics/Predict_names.csv")))

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
print ("X_predict shape: " + str(X_predict.shape))
print ("Y_predict shape: " + str(Y_predict.shape))
# Out:
# number of training examples = 1182
# number of test examples = 393
# X_train shape: (1182, 2604)
# Y_train shape: (1182, 3)
# X_test shape: (393, 2604)
# Y_test shape: (393, 3)
# X_predict shape: (393, 2604)
# Y_predict shape: (393, 3)

# %%
# GRADED FUNCTION: HappyModel

def HappyModel(input_shape, n_layers, l1_coef, l2_coef):
    """
    Implementation of the HappyModel.
    
    Arguments:
    input_shape -- shape of the images of the dataset
        (height, width, channels) as a tuple.  
        Note that this does not include the 'batch' as a dimension.
        If you have a batch like 'X_train', 
        then you can provide the input_shape using
        X_train.shape[1:]

    Returns:
    model -- a Model() instance in Keras
    """
    
    ### START CODE HERE ###
    # Feel free to use the suggested outline in the text above to get started, and run through the whole
    # exercise (including the later portions of this notebook) once. The come back also try out other
    # network architectures as well. 
    
    # Define the input placeholder as a tensor with shape input_shape. Think of this as your input image!
    X_input = Input(input_shape)
    
    

    # Deep_neural network with  n_layers (1)
    #X = Dense(64, activation= "linear", name='fc_start', use_bias='false', kernel_initializer="glorot_normal",
    #          kernel_regularizer=tf.keras.regularizers.l1_l2(l1_coef, l2_coef))(X_input)
    #X = BatchNormalization(axis = 1, name = 'bn_start')(X)
    #X = Activation('relu')(X)
    
    #for i in range(n_layers):
    #    X = Dense(64, activation= "linear", name='fc_'+str(i), use_bias='false', kernel_initializer="glorot_normal",
    #          kernel_regularizer=tf.keras.regularizers.l1_l2(l1_coef, l2_coef))(X)
    #    X = BatchNormalization(axis = 1, name = 'bn_'+str(i))(X)
    #    X = Activation('relu')(X)
        
    #X = Dense(1, activation= "relu", name='fc_end', use_bias='True', kernel_initializer="glorot_normal",
    #          kernel_regularizer=tf.keras.regularizers.l1_l2(l1_coef, l2_coef))(X)
    #X = BatchNormalization(axis = 1, name = 'bn_end')(X)
    
    #X = Dense(3, use_bias=True)(X)
    #X = Activation('softmax')(X)
    
    #1/2 fully_connected layer neural network to predict nteractions (Francois Chollet) (2)
    X = Dense(32, activation="relu")(X_input)
    X = Dropout(0.5)(X)
    X = Dense(32, activation="relu")(X)
    X = Dense(3, activation="softmax")(X)
    
    
    #1 fully_connected layer neural network to predict MoA (Francois Chollet) (3)
    #X = Dense(64, activation="relu")(X_input)
    #X = Dropout(0.5)(X)
    #X = Dense(1, activation="softmax")(X)

    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs = X_input, outputs = X, name='HappyModel')
    
    ### END CODE HERE ###
    
    return model

# %% [markdown]
# You have now built a function to describe your model. To train and test this model, there are four steps in Keras:
# 1. Create the model by calling the function above
#
# 2. Compile the model by calling `model.compile(optimizer = "...", loss = "...", metrics = ["accuracy"])`
#
# 3. Train the model on train data by calling `model.fit(x = ..., y = ..., epochs = ..., batch_size = ...)`
#
# 4. Test the model on test data by calling `model.evaluate(x = ..., y = ...)`
#
# If you want to know more about `model.compile()`, `model.fit()`, `model.evaluate()` and their arguments, refer to the official [Keras documentation](https://keras.io/models/model/).

# %% [markdown]
# #### Step 1: create the model.
# **Hint**:
# The `input_shape` parameter is a tuple (height, width, channels).  It excludes the batch number.
# Try `X_train.shape[1:]` as the `input_shape`.

# %%
n_layers = 10
l1_coef = 0.1
l2_coef = 0.1
### START CODE HERE ### (1 line)
happyModel = HappyModel(X_train.shape[1:],n_layers, l1_coef, l2_coef)
### END CODE HERE ###
# Out:
# (2604,)

# %% [markdown]
# #### Step 2: compile the model
#
# **Hint**:
# Optimizers you can try include `'adam'`, `'sgd'` or others.  See the documentation for [optimizers](https://keras.io/optimizers/)
# The "happiness detection" is a binary classification problem.  The loss function that you can use is `'binary_cross_entropy'`.  Note that `'categorical_cross_entropy'` won't work with your data set as its formatted, because the data is an array of 0 or 1 rather than two arrays (one for each category).  Documentation for [losses](https://keras.io/losses/)

# %%
happyModel.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy", tf.keras.metrics.Precision()])

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %% [markdown]
# #### Step 3: train the model
#
# **Hint**:
# Use the `'X_train'`, `'Y_train'` variables.  Use integers for the epochs and batch_size
#
# **Note**: If you run `fit()` again, the `model` will continue to train with the parameters it has already learned instead of reinitializing them.

# %%
class_weight = {0: 100.,
                1: 1.,
                2: 500.}

happyModel.fit(x = X_train, y = Y_train, epochs = 300, steps_per_epoch=16, class_weight=class_weight,  callbacks=[tensorboard_callback]) # batch_size = 64
# Out:
# Epoch 1/300
# 16/16 [==============================] - 0s 6ms/step - loss: 31.6536 - accuracy: 0.3393 - precision_11: 0.3423
# Epoch 2/300
# 16/16 [==============================] - 0s 2ms/step - loss: 17.8347 - accuracy: 0.1641 - precision_11: 0.1477
# Epoch 3/300
# 16/16 [==============================] - 0s 2ms/step - loss: 14.9918 - accuracy: 0.1582 - precision_11: 0.1401
# Epoch 4/300
# 16/16 [==============================] - 0s 2ms/step - loss: 12.6915 - accuracy: 0.1404 - precision_11: 0.1322
# Epoch 5/300
# 16/16 [==============================] - 0s 2ms/step - loss: 10.6118 - accuracy: 0.1455 - precision_11: 0.1446
# Epoch 6/300
# 16/16 [==============================] - 0s 2ms/step - loss: 11.3488 - accuracy: 0.1387 - precision_11: 0.1308
# Epoch 7/300
# 16/16 [==============================] - 0s 2ms/step - loss: 10.4861 - accuracy: 0.1413 - precision_11: 0.1398
# Epoch 8/300
# 16/16 [==============================] - 0s 2ms/step - loss: 9.5573 - accuracy: 0.1320 - precision_11: 0.1317
# Epoch 9/300
# 16/16 [==============================] - 0s 2ms/step - loss: 11.1406 - accuracy: 0.1481 - precision_11: 0.1455
# Epoch 10/300
# 16/16 [==============================] - 0s 2ms/step - loss: 8.8294 - accuracy: 0.1354 - precision_11: 0.1306
# Epoch 11/300
# 16/16 [==============================] - 0s 2ms/step - loss: 7.9273 - accuracy: 0.1438 - precision_11: 0.1433
# Epoch 12/300
# 16/16 [==============================] - 0s 2ms/step - loss: 7.5631 - accuracy: 0.1371 - precision_11: 0.1378
# Epoch 13/300
# 16/16 [==============================] - 0s 2ms/step - loss: 7.5271 - accuracy: 0.1430 - precision_11: 0.1500
# Epoch 14/300
# 16/16 [==============================] - 0s 2ms/step - loss: 9.7394 - accuracy: 0.1447 - precision_11: 0.1413
# Epoch 15/300
# 16/16 [==============================] - 0s 2ms/step - loss: 7.3792 - accuracy: 0.1514 - precision_11: 0.1563
# Epoch 16/300
# 16/16 [==============================] - 0s 2ms/step - loss: 8.8826 - accuracy: 0.1404 - precision_11: 0.1433
# Epoch 17/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.9507 - accuracy: 0.1506 - precision_11: 0.1549
# Epoch 18/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.5089 - accuracy: 0.1557 - precision_11: 0.1593
# Epoch 19/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.0882 - accuracy: 0.1582 - precision_11: 0.1616
# Epoch 20/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.1452 - accuracy: 0.1548 - precision_11: 0.1593
# Epoch 21/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.0613 - accuracy: 0.1641 - precision_11: 0.1665
# Epoch 22/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.1810 - accuracy: 0.1717 - precision_11: 0.1743
# Epoch 23/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.4401 - accuracy: 0.1794 - precision_11: 0.1810
# Epoch 24/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.3951 - accuracy: 0.1836 - precision_11: 0.1856
# Epoch 25/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.8294 - accuracy: 0.1963 - precision_11: 0.1985
# Epoch 26/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.2376 - accuracy: 0.1954 - precision_11: 0.2044
# Epoch 27/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.5963 - accuracy: 0.2047 - precision_11: 0.2156
# Epoch 28/300
# 16/16 [==============================] - 0s 2ms/step - loss: 7.1816 - accuracy: 0.1878 - precision_11: 0.1924
# Epoch 29/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.9197 - accuracy: 0.1768 - precision_11: 0.1716
# Epoch 30/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.8631 - accuracy: 0.1684 - precision_11: 0.1705
# Epoch 31/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.4910 - accuracy: 0.1701 - precision_11: 0.1782
# Epoch 32/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.9630 - accuracy: 0.1607 - precision_11: 0.1642
# Epoch 33/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.5964 - accuracy: 0.1743 - precision_11: 0.1799
# Epoch 34/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.5276 - accuracy: 0.1819 - precision_11: 0.1875
# Epoch 35/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.0520 - accuracy: 0.1853 - precision_11: 0.1856
# Epoch 36/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.9173 - accuracy: 0.1937 - precision_11: 0.1987
# Epoch 37/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.8534 - accuracy: 0.1819 - precision_11: 0.1872
# Epoch 38/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.6862 - accuracy: 0.1844 - precision_11: 0.1921
# Epoch 39/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.9632 - accuracy: 0.1963 - precision_11: 0.2034
# Epoch 40/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.6778 - accuracy: 0.1895 - precision_11: 0.1967
# Epoch 41/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.9548 - accuracy: 0.1988 - precision_11: 0.2048
# Epoch 42/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.0181 - accuracy: 0.2149 - precision_11: 0.2124
# Epoch 43/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.5899 - accuracy: 0.2191 - precision_11: 0.2206
# Epoch 44/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.9811 - accuracy: 0.1997 - precision_11: 0.2115
# Epoch 45/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.1953 - accuracy: 0.2174 - precision_11: 0.2316
# Epoch 46/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.7487 - accuracy: 0.2132 - precision_11: 0.2176
# Epoch 47/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.3750 - accuracy: 0.2191 - precision_11: 0.2363
# Epoch 48/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.0345 - accuracy: 0.2377 - precision_11: 0.2486
# Epoch 49/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.6414 - accuracy: 0.2166 - precision_11: 0.2256
# Epoch 50/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.4083 - accuracy: 0.2242 - precision_11: 0.2337
# Epoch 51/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.3895 - accuracy: 0.2386 - precision_11: 0.2460
# Epoch 52/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.1838 - accuracy: 0.2403 - precision_11: 0.2498
# Epoch 53/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.2630 - accuracy: 0.2479 - precision_11: 0.2597
# Epoch 54/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.7065 - accuracy: 0.2707 - precision_11: 0.2732
# Epoch 55/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.3437 - accuracy: 0.2538 - precision_11: 0.2694
# Epoch 56/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.7313 - accuracy: 0.2538 - precision_11: 0.2692
# Epoch 57/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.5304 - accuracy: 0.2343 - precision_11: 0.2452
# Epoch 58/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.0884 - accuracy: 0.2437 - precision_11: 0.2596
# Epoch 59/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8951 - accuracy: 0.2343 - precision_11: 0.2527
# Epoch 60/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8171 - accuracy: 0.2352 - precision_11: 0.2450
# Epoch 61/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.6137 - accuracy: 0.2310 - precision_11: 0.2400
# Epoch 62/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.7354 - accuracy: 0.2597 - precision_11: 0.2706
# Epoch 63/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.7912 - accuracy: 0.2580 - precision_11: 0.2725
# Epoch 64/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.1939 - accuracy: 0.2623 - precision_11: 0.2795
# Epoch 65/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.6115 - accuracy: 0.2563 - precision_11: 0.2758
# Epoch 66/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.9276 - accuracy: 0.2733 - precision_11: 0.2939
# Epoch 67/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8849 - accuracy: 0.2657 - precision_11: 0.2863
# Epoch 68/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.2162 - accuracy: 0.2817 - precision_11: 0.3032
# Epoch 69/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3805 - accuracy: 0.2648 - precision_11: 0.2832
# Epoch 70/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5728 - accuracy: 0.2783 - precision_11: 0.3010
# Epoch 71/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.8897 - accuracy: 0.2919 - precision_11: 0.3011
# Epoch 72/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.0800 - accuracy: 0.2885 - precision_11: 0.3033
# Epoch 73/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8442 - accuracy: 0.2860 - precision_11: 0.3049
# Epoch 74/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.7930 - accuracy: 0.2944 - precision_11: 0.3083
# Epoch 75/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.6329 - accuracy: 0.2902 - precision_11: 0.3016
# Epoch 76/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8713 - accuracy: 0.2800 - precision_11: 0.2888
# Epoch 77/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.0073 - accuracy: 0.2936 - precision_11: 0.3136
# Epoch 78/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5034 - accuracy: 0.2783 - precision_11: 0.2976
# Epoch 79/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.6660 - accuracy: 0.3266 - precision_11: 0.3406
# Epoch 80/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3921 - accuracy: 0.3308 - precision_11: 0.3534
# Epoch 81/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.2524 - accuracy: 0.3393 - precision_11: 0.3626
# Epoch 82/300
# 16/16 [==============================] - 0s 2ms/step - loss: 6.9193 - accuracy: 0.3249 - precision_11: 0.3422
# Epoch 83/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5906 - accuracy: 0.3206 - precision_11: 0.3464
# Epoch 84/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.9790 - accuracy: 0.3012 - precision_11: 0.3247
# Epoch 85/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.4171 - accuracy: 0.3096 - precision_11: 0.3260
# Epoch 86/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3817 - accuracy: 0.3266 - precision_11: 0.3434
# Epoch 87/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3150 - accuracy: 0.3426 - precision_11: 0.3635
# Epoch 88/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.2054 - accuracy: 0.2986 - precision_11: 0.3123
# Epoch 89/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.6540 - accuracy: 0.2860 - precision_11: 0.3025
# Epoch 90/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5329 - accuracy: 0.2893 - precision_11: 0.3020
# Epoch 91/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4177 - accuracy: 0.3130 - precision_11: 0.3299
# Epoch 92/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.9600 - accuracy: 0.3139 - precision_11: 0.3321
# Epoch 93/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1764 - accuracy: 0.3139 - precision_11: 0.3343
# Epoch 94/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.4600 - accuracy: 0.3215 - precision_11: 0.3352
# Epoch 95/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7421 - accuracy: 0.3469 - precision_11: 0.3729
# Epoch 96/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5609 - accuracy: 0.3367 - precision_11: 0.3514
# Epoch 97/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5044 - accuracy: 0.3350 - precision_11: 0.3474
# Epoch 98/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.5712 - accuracy: 0.3181 - precision_11: 0.3277
# Epoch 99/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.4768 - accuracy: 0.3350 - precision_11: 0.3530
# Epoch 100/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1330 - accuracy: 0.3003 - precision_11: 0.3165
# Epoch 101/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.7298 - accuracy: 0.3003 - precision_11: 0.3101
# Epoch 102/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1233 - accuracy: 0.3105 - precision_11: 0.3311
# Epoch 103/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.9625 - accuracy: 0.3240 - precision_11: 0.3406
# Epoch 104/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9262 - accuracy: 0.3477 - precision_11: 0.3554
# Epoch 105/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9824 - accuracy: 0.3486 - precision_11: 0.3623
# Epoch 106/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.1538 - accuracy: 0.3460 - precision_11: 0.3641
# Epoch 107/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3610 - accuracy: 0.3342 - precision_11: 0.3532
# Epoch 108/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1345 - accuracy: 0.3350 - precision_11: 0.3520
# Epoch 109/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9528 - accuracy: 0.3333 - precision_11: 0.3514
# Epoch 110/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3756 - accuracy: 0.3384 - precision_11: 0.3540
# Epoch 111/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.2484 - accuracy: 0.3325 - precision_11: 0.3480
# Epoch 112/300
# 16/16 [==============================] - 0s 3ms/step - loss: 2.6746 - accuracy: 0.3587 - precision_11: 0.3735
# Epoch 113/300
# 16/16 [==============================] - 0s 3ms/step - loss: 3.4254 - accuracy: 0.3680 - precision_11: 0.3929
# Epoch 114/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.1114 - accuracy: 0.3706 - precision_11: 0.3923
# Epoch 115/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3803 - accuracy: 0.4044 - precision_11: 0.4183
# Epoch 116/300
# 16/16 [==============================] - 0s 3ms/step - loss: 3.1769 - accuracy: 0.3646 - precision_11: 0.3845
# Epoch 117/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1921 - accuracy: 0.3765 - precision_11: 0.3942
# Epoch 118/300
# 16/16 [==============================] - 0s 3ms/step - loss: 2.8778 - accuracy: 0.3875 - precision_11: 0.4052
# Epoch 119/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9427 - accuracy: 0.3883 - precision_11: 0.3976
# Epoch 120/300
# 16/16 [==============================] - 0s 3ms/step - loss: 3.1705 - accuracy: 0.4196 - precision_11: 0.4451
# Epoch 121/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5833 - accuracy: 0.4103 - precision_11: 0.4356
# Epoch 122/300
# 16/16 [==============================] - 0s 3ms/step - loss: 3.2055 - accuracy: 0.3993 - precision_11: 0.4186
# Epoch 123/300
# 16/16 [==============================] - 0s 3ms/step - loss: 3.4872 - accuracy: 0.4061 - precision_11: 0.4233
# Epoch 124/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0901 - accuracy: 0.3866 - precision_11: 0.4031
# Epoch 125/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.0511 - accuracy: 0.3680 - precision_11: 0.3827
# Epoch 126/300
# 16/16 [==============================] - 0s 3ms/step - loss: 3.2145 - accuracy: 0.4036 - precision_11: 0.4199
# Epoch 127/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5803 - accuracy: 0.4095 - precision_11: 0.4283
# Epoch 128/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.2740 - accuracy: 0.3993 - precision_11: 0.4111
# Epoch 129/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1439 - accuracy: 0.3875 - precision_11: 0.4018
# Epoch 130/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7990 - accuracy: 0.3934 - precision_11: 0.4111
# Epoch 131/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7616 - accuracy: 0.4044 - precision_11: 0.4228
# Epoch 132/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6809 - accuracy: 0.4213 - precision_11: 0.4375
# Epoch 133/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6345 - accuracy: 0.4272 - precision_11: 0.4416
# Epoch 134/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3180 - accuracy: 0.4036 - precision_11: 0.4144
# Epoch 135/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9298 - accuracy: 0.4315 - precision_11: 0.4494
# Epoch 136/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0119 - accuracy: 0.4027 - precision_11: 0.4167
# Epoch 137/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7344 - accuracy: 0.3968 - precision_11: 0.4134
# Epoch 138/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8199 - accuracy: 0.4146 - precision_11: 0.4287
# Epoch 139/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5300 - accuracy: 0.4196 - precision_11: 0.4345
# Epoch 140/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5958 - accuracy: 0.3934 - precision_11: 0.4031
# Epoch 141/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9966 - accuracy: 0.3849 - precision_11: 0.4029
# Epoch 142/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4580 - accuracy: 0.4146 - precision_11: 0.4305
# Epoch 143/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.1030 - accuracy: 0.4179 - precision_11: 0.4355
# Epoch 144/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.2842 - accuracy: 0.4255 - precision_11: 0.4374
# Epoch 145/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.4528 - accuracy: 0.3790 - precision_11: 0.3890
# Epoch 146/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.4923 - accuracy: 0.4129 - precision_11: 0.4201
# Epoch 147/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.7210 - accuracy: 0.4205 - precision_11: 0.4364
# Epoch 148/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.2223 - accuracy: 0.3959 - precision_11: 0.4108
# Epoch 149/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.2502 - accuracy: 0.3968 - precision_11: 0.4099
# Epoch 150/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1328 - accuracy: 0.4052 - precision_11: 0.4179
# Epoch 151/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5791 - accuracy: 0.4230 - precision_11: 0.4397
# Epoch 152/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.0501 - accuracy: 0.4095 - precision_11: 0.4274
# Epoch 153/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6599 - accuracy: 0.4450 - precision_11: 0.4597
# Epoch 154/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8724 - accuracy: 0.3959 - precision_11: 0.4119
# Epoch 155/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1043 - accuracy: 0.3993 - precision_11: 0.4080
# Epoch 156/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7789 - accuracy: 0.4230 - precision_11: 0.4391
# Epoch 157/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3267 - accuracy: 0.4019 - precision_11: 0.4058
# Epoch 158/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3623 - accuracy: 0.4247 - precision_11: 0.4352
# Epoch 159/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7041 - accuracy: 0.4205 - precision_11: 0.4332
# Epoch 160/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6710 - accuracy: 0.4281 - precision_11: 0.4342
# Epoch 161/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7692 - accuracy: 0.4425 - precision_11: 0.4511
# Epoch 162/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8192 - accuracy: 0.4459 - precision_11: 0.4503
# Epoch 163/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7968 - accuracy: 0.4349 - precision_11: 0.4409
# Epoch 164/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0297 - accuracy: 0.4585 - precision_11: 0.4649
# Epoch 165/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7382 - accuracy: 0.4636 - precision_11: 0.4690
# Epoch 166/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5229 - accuracy: 0.4755 - precision_11: 0.4786
# Epoch 167/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9084 - accuracy: 0.4585 - precision_11: 0.4642
# Epoch 168/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.6288 - accuracy: 0.4619 - precision_11: 0.4659
# Epoch 169/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0999 - accuracy: 0.4509 - precision_11: 0.4565
# Epoch 170/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8050 - accuracy: 0.4543 - precision_11: 0.4625
# Epoch 171/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1823 - accuracy: 0.4670 - precision_11: 0.4729
# Epoch 172/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8571 - accuracy: 0.4687 - precision_11: 0.4734
# Epoch 173/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.0975 - accuracy: 0.4281 - precision_11: 0.4401
# Epoch 174/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9870 - accuracy: 0.4357 - precision_11: 0.4453
# Epoch 175/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7628 - accuracy: 0.4365 - precision_11: 0.4476
# Epoch 176/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.6511 - accuracy: 0.4374 - precision_11: 0.4413
# Epoch 177/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5344 - accuracy: 0.4332 - precision_11: 0.4410
# Epoch 178/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3043 - accuracy: 0.4425 - precision_11: 0.4475
# Epoch 179/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9053 - accuracy: 0.4772 - precision_11: 0.4832
# Epoch 180/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1376 - accuracy: 0.4763 - precision_11: 0.4817
# Epoch 181/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.4345 - accuracy: 0.4518 - precision_11: 0.4580
# Epoch 182/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9729 - accuracy: 0.4577 - precision_11: 0.4654
# Epoch 183/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1083 - accuracy: 0.4585 - precision_11: 0.4596
# Epoch 184/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6117 - accuracy: 0.4992 - precision_11: 0.5079
# Epoch 185/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3198 - accuracy: 0.4763 - precision_11: 0.4831
# Epoch 186/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.2059 - accuracy: 0.4949 - precision_11: 0.5026
# Epoch 187/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.1756 - accuracy: 0.4898 - precision_11: 0.5022
# Epoch 188/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7345 - accuracy: 0.4814 - precision_11: 0.4883
# Epoch 189/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4414 - accuracy: 0.4721 - precision_11: 0.4813
# Epoch 190/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8836 - accuracy: 0.4721 - precision_11: 0.4777
# Epoch 191/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3524 - accuracy: 0.4628 - precision_11: 0.4688
# Epoch 192/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5055 - accuracy: 0.4788 - precision_11: 0.4849
# Epoch 193/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1051 - accuracy: 0.4146 - precision_11: 0.4202
# Epoch 194/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.2199 - accuracy: 0.4171 - precision_11: 0.4233
# Epoch 195/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5648 - accuracy: 0.4594 - precision_11: 0.4626
# Epoch 196/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0643 - accuracy: 0.4670 - precision_11: 0.4739
# Epoch 197/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3498 - accuracy: 0.4501 - precision_11: 0.4488
# Epoch 198/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1211 - accuracy: 0.4628 - precision_11: 0.4662
# Epoch 199/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6288 - accuracy: 0.4712 - precision_11: 0.4787
# Epoch 200/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3257 - accuracy: 0.4780 - precision_11: 0.4887
# Epoch 201/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8533 - accuracy: 0.4797 - precision_11: 0.4827
# Epoch 202/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4256 - accuracy: 0.4822 - precision_11: 0.4900
# Epoch 203/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9601 - accuracy: 0.4898 - precision_11: 0.4987
# Epoch 204/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8314 - accuracy: 0.4636 - precision_11: 0.4706
# Epoch 205/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6463 - accuracy: 0.4653 - precision_11: 0.4703
# Epoch 206/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4508 - accuracy: 0.4670 - precision_11: 0.4744
# Epoch 207/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1299 - accuracy: 0.5042 - precision_11: 0.5118
# Epoch 208/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6578 - accuracy: 0.5127 - precision_11: 0.5226
# Epoch 209/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0471 - accuracy: 0.5085 - precision_11: 0.5151
# Epoch 210/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0853 - accuracy: 0.5068 - precision_11: 0.5100
# Epoch 211/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8502 - accuracy: 0.5203 - precision_11: 0.5246
# Epoch 212/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0482 - accuracy: 0.5118 - precision_11: 0.5177
# Epoch 213/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8066 - accuracy: 0.4882 - precision_11: 0.4914
# Epoch 214/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9105 - accuracy: 0.5051 - precision_11: 0.5126
# Epoch 215/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7926 - accuracy: 0.5076 - precision_11: 0.5142
# Epoch 216/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.2059 - accuracy: 0.5228 - precision_11: 0.5282
# Epoch 217/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.2910 - accuracy: 0.4924 - precision_11: 0.4983
# Epoch 218/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6070 - accuracy: 0.4628 - precision_11: 0.4696
# Epoch 219/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4670 - accuracy: 0.4941 - precision_11: 0.4991
# Epoch 220/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0303 - accuracy: 0.5008 - precision_11: 0.5069
# Epoch 221/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.2712 - accuracy: 0.5296 - precision_11: 0.5337
# Epoch 222/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.0804 - accuracy: 0.5085 - precision_11: 0.5146
# Epoch 223/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3223 - accuracy: 0.5017 - precision_11: 0.5069
# Epoch 224/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.0912 - accuracy: 0.4831 - precision_11: 0.4878
# Epoch 225/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5493 - accuracy: 0.5372 - precision_11: 0.5417
# Epoch 226/300
# 16/16 [==============================] - 0s 2ms/step - loss: 1.9723 - accuracy: 0.5381 - precision_11: 0.5431
# Epoch 227/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8725 - accuracy: 0.5059 - precision_11: 0.5078
# Epoch 228/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8116 - accuracy: 0.5338 - precision_11: 0.5385
# Epoch 229/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5086 - accuracy: 0.5381 - precision_11: 0.5463
# Epoch 230/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6278 - accuracy: 0.5406 - precision_11: 0.5469
# Epoch 231/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.6298 - accuracy: 0.4992 - precision_11: 0.5039
# Epoch 232/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8142 - accuracy: 0.4746 - precision_11: 0.4794
# Epoch 233/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5417 - accuracy: 0.4645 - precision_11: 0.4727
# Epoch 234/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5391 - accuracy: 0.4763 - precision_11: 0.4810
# Epoch 235/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.1868 - accuracy: 0.4949 - precision_11: 0.4996
# Epoch 236/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.1481 - accuracy: 0.5051 - precision_11: 0.5090
# Epoch 237/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.7654 - accuracy: 0.4788 - precision_11: 0.4824
# Epoch 238/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8797 - accuracy: 0.4780 - precision_11: 0.4824
# Epoch 239/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6246 - accuracy: 0.4509 - precision_11: 0.4541
# Epoch 240/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.1480 - accuracy: 0.4679 - precision_11: 0.4690
# Epoch 241/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8534 - accuracy: 0.4738 - precision_11: 0.4784
# Epoch 242/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4340 - accuracy: 0.4839 - precision_11: 0.4892
# Epoch 243/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.1134 - accuracy: 0.4898 - precision_11: 0.4940
# Epoch 244/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0838 - accuracy: 0.5161 - precision_11: 0.5190
# Epoch 245/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3420 - accuracy: 0.5110 - precision_11: 0.5129
# Epoch 246/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4704 - accuracy: 0.5144 - precision_11: 0.5184
# Epoch 247/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5886 - accuracy: 0.5195 - precision_11: 0.5239
# Epoch 248/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5605 - accuracy: 0.5178 - precision_11: 0.5223
# Epoch 249/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6550 - accuracy: 0.5042 - precision_11: 0.5081
# Epoch 250/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9534 - accuracy: 0.5135 - precision_11: 0.5211
# Epoch 251/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4741 - accuracy: 0.5110 - precision_11: 0.5141
# Epoch 252/300
# 16/16 [==============================] - 0s 2ms/step - loss: 1.8925 - accuracy: 0.5144 - precision_11: 0.5176
# Epoch 253/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6019 - accuracy: 0.5254 - precision_11: 0.5287
# Epoch 254/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.2604 - accuracy: 0.5406 - precision_11: 0.5450
# Epoch 255/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6885 - accuracy: 0.5491 - precision_11: 0.5528
# Epoch 256/300
# 16/16 [==============================] - 0s 2ms/step - loss: 1.8659 - accuracy: 0.5550 - precision_11: 0.5583
# Epoch 257/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.0878 - accuracy: 0.5372 - precision_11: 0.5410
# Epoch 258/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3984 - accuracy: 0.5465 - precision_11: 0.5526
# Epoch 259/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3670 - accuracy: 0.5660 - precision_11: 0.5677
# Epoch 260/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3586 - accuracy: 0.5677 - precision_11: 0.5725
# Epoch 261/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3468 - accuracy: 0.5347 - precision_11: 0.5419
# Epoch 262/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.1619 - accuracy: 0.5389 - precision_11: 0.5412
# Epoch 263/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5261 - accuracy: 0.5499 - precision_11: 0.5545
# Epoch 264/300
# 16/16 [==============================] - 0s 2ms/step - loss: 1.9527 - accuracy: 0.5457 - precision_11: 0.5500
# Epoch 265/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9543 - accuracy: 0.5448 - precision_11: 0.5475
# Epoch 266/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.2133 - accuracy: 0.5254 - precision_11: 0.5274
# Epoch 267/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9546 - accuracy: 0.5406 - precision_11: 0.5461
# Epoch 268/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.7440 - accuracy: 0.5431 - precision_11: 0.5438
# Epoch 269/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.9016 - accuracy: 0.5618 - precision_11: 0.5669
# Epoch 270/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.8921 - accuracy: 0.5609 - precision_11: 0.5651
# Epoch 271/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9298 - accuracy: 0.5584 - precision_11: 0.5605
# Epoch 272/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3408 - accuracy: 0.5474 - precision_11: 0.5500
# Epoch 273/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5390 - accuracy: 0.5584 - precision_11: 0.5614
# Epoch 274/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3121 - accuracy: 0.5347 - precision_11: 0.5421
# Epoch 275/300
# 16/16 [==============================] - 0s 2ms/step - loss: 1.9186 - accuracy: 0.5694 - precision_11: 0.5736
# Epoch 276/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.1641 - accuracy: 0.5677 - precision_11: 0.5756
# Epoch 277/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3069 - accuracy: 0.5635 - precision_11: 0.5692
# Epoch 278/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.9353 - accuracy: 0.5778 - precision_11: 0.5808
# Epoch 279/300
# 16/16 [==============================] - 0s 2ms/step - loss: 1.6669 - accuracy: 0.6024 - precision_11: 0.6058
# Epoch 280/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.2780 - accuracy: 0.5550 - precision_11: 0.5582
# Epoch 281/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.5399 - accuracy: 0.5516 - precision_11: 0.5523
# Epoch 282/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4509 - accuracy: 0.5618 - precision_11: 0.5654
# Epoch 283/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.3746 - accuracy: 0.5761 - precision_11: 0.5791
# Epoch 284/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6070 - accuracy: 0.5347 - precision_11: 0.5372
# Epoch 285/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3901 - accuracy: 0.5558 - precision_11: 0.5596
# Epoch 286/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.1217 - accuracy: 0.5787 - precision_11: 0.5834
# Epoch 287/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.6658 - accuracy: 0.5575 - precision_11: 0.5605
# Epoch 288/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.8722 - accuracy: 0.5372 - precision_11: 0.5398
# Epoch 289/300
# 16/16 [==============================] - 0s 2ms/step - loss: 4.1287 - accuracy: 0.5398 - precision_11: 0.5392
# Epoch 290/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.5557 - accuracy: 0.5228 - precision_11: 0.5247
# Epoch 291/300
# 16/16 [==============================] - 0s 2ms/step - loss: 5.3875 - accuracy: 0.4932 - precision_11: 0.4936
# Epoch 292/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.9297 - accuracy: 0.4154 - precision_11: 0.4170
# Epoch 293/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.6827 - accuracy: 0.4560 - precision_11: 0.4596
# Epoch 294/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.1582 - accuracy: 0.4932 - precision_11: 0.4962
# Epoch 295/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.6042 - accuracy: 0.4941 - precision_11: 0.4987
# Epoch 296/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.3219 - accuracy: 0.5127 - precision_11: 0.5164
# Epoch 297/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.9549 - accuracy: 0.5085 - precision_11: 0.5116
# Epoch 298/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.6544 - accuracy: 0.4797 - precision_11: 0.4833
# Epoch 299/300
# 16/16 [==============================] - 0s 2ms/step - loss: 3.0823 - accuracy: 0.5245 - precision_11: 0.5297
# Epoch 300/300
# 16/16 [==============================] - 0s 2ms/step - loss: 2.4208 - accuracy: 0.5296 - precision_11: 0.5318

# %% [markdown]
# #### Step 4: evaluate model
# **Hint**:
# Use the `'X_test'` and `'Y_test'` variables to evaluate the model's performance.

# %%
### START CODE HERE ### (1 line)
preds = happyModel.evaluate(X_test, Y_test, steps=1)

### END CODE HERE ###
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
print ("Test Precision = " + str(preds[2]))
print(preds)


y_pred = pd.DataFrame(happyModel.predict(X_predict))#, batch_size=64, verbose=1))
#y_pred_bool = np.argmax(y_pred, axis=1)
y_pred = (y_pred == y_pred.max(axis=1)[:,None]).astype(int)


y_true = Y_predict
target_names = ['antagonism', 'neutral', 'synergy'] 


print(classification_report(y_true, y_pred, target_names=target_names))


#from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix
#y_pred1 = model.predict(X_test)
#y_pred = np.argmax(y_pred1, axis=1)

# Print f1, precision, and recall scores
#print(precision_score(y_test, y_pred , average="macro"))
#print(recall_score(y_test, y_pred , average="macro"))
#print(f1_score(y_test, y_pred , average="macro"))
# Out:
# 1/1 [==============================] - 0s 784us/step - loss: 0.9403 - accuracy: 0.5802 - precision_11: 0.5806
#
# Loss = 0.9403237104415894
# Test Accuracy = 0.580152690410614
# Test Precision = 0.5805626511573792
# [0.9403237104415894, 0.580152690410614, 0.5805626511573792]
#               precision    recall  f1-score   support
#
#   antagonism       0.19      0.39      0.25        31
#      neutral       0.87      0.58      0.70       325
#      synergy       0.13      0.38      0.19        37
#
#    micro avg       0.55      0.55      0.55       393
#    macro avg       0.40      0.45      0.38       393
# weighted avg       0.75      0.55      0.62       393
#  samples avg       0.55      0.55      0.55       393

# %%
happyModel.summary()
# Out:
# Model: "HappyModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2604)]            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                83360
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 84,515
# Trainable params: 84,515
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %tensorboard --logdir logs
# Out:
# ERROR: Could not find `tensorboard`. Please ensure that your PATH
# contains an executable `tensorboard` program, or explicitly specify
# the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
# environment variable.

# %%
#For MoA prediction
#print(happyModel.predict(X_predict))
#prediction_data = pd.DataFrame(happyModel.predict(X_predict))

#prediction_data['drugs'] = names_predictions
#prediction_data.columns = ['cell_wall', 'membrane_stess', 'dna', 'protein_synthesis', "drugs"]
#cols = prediction_data.columns.tolist()
#cols = cols[-1:] + cols[:-1]
#prediction_data = prediction_data[cols]
#print(prediction_data)

#prediction_data.to_csv("/Users/bassler/Desktop/Documents/dl_chem_genetics/Prediction_neural_network.csv", index=False, sep='\t')

# %% [markdown]
# #### Expected performance
# If your `happyModel()` function worked, its accuracy should be better than random guessing (50% accuracy).
#
# To give you a point of comparison, our model gets around **95% test accuracy in 40 epochs** (and 99% train accuracy) with a mini batch size of 16 and "adam" optimizer.

# %% [markdown]
# #### Tips for improving your model
#
# If you have not yet achieved a very good accuracy (>= 80%), here are some things tips:
#
# - Use blocks of CONV->BATCHNORM->RELU such as:
# ```python
# X = Conv2D(32, (3, 3), strides = (1, 1), name = 'conv0')(X)
# X = BatchNormalization(axis = 3, name = 'bn0')(X)
# X = Activation('relu')(X)
# ```
# until your height and width dimensions are quite low and your number of channels quite large (≈32 for example).
# You can then flatten the volume and use a fully-connected layer.
# - Use MAXPOOL after such blocks.  It will help you lower the dimension in height and width.
# - Change your optimizer. We find 'adam' works well.
# - If you get memory issues, lower your batch_size (e.g. 12 )
# - Run more epochs until you see the train accuracy no longer improves.
#
# **Note**: If you perform hyperparameter tuning on your model, the test set actually becomes a dev set, and your model might end up overfitting to the test (dev) set. Normally, you'll want separate dev and test sets.  The dev set is used for parameter tuning, and the test set is used once to estimate the model's performance in production.

# %% [markdown]
# ## 3 - Conclusion
#
# Congratulations, you have created a proof of concept for "happiness detection"!

# %% [markdown]
# ## Key Points to remember
# - Keras is a tool we recommend for rapid prototyping. It allows you to quickly try out different model architectures.
# - Remember The four steps in Keras:
#
#
# 1. Create
# 2. Compile
# 3. Fit/Train
# 4. Evaluate/Test

# %% [markdown]
# ## 5 - Other useful functions in Keras (Optional)
#
# Two other basic features of Keras that you'll find useful are:
# - `model.summary()`: prints the details of your layers in a table with the sizes of its inputs/outputs
# - `plot_model()`: plots your graph in a nice layout. You can even save it as ".png" using SVG() if you'd like to share it on social media ;). It is saved in "File" then "Open..." in the upper bar of the notebook.
#
# Run the following code.

# %%
#happyModel.summary()

# %%
#plot_model(happyModel, to_file='HappyModel.png', show_shapes=True, rankdir="LR")
#SVG(model_to_dot(happyModel).create(prog='dot', format='svg'))
